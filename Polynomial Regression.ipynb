# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x = np.array([1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22])
y = np.array([100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100])

# %%
len(x)
# Out:
# 18

# %%
print(min(x))
print(max(x))
# Out:
# 1
# 22

# %%
colors = random.sample(range(1, 100), len(x))

# %%
plt.scatter(x, y, c = colors, cmap = "viridis")

plt.colorbar()
plt.grid()
plt.show()

# %%
mymodel = np.poly1d(np.polyfit(x, y, 3))
myline = np.linspace(1, 22, 100)
plt.scatter(x, y, c = colors, cmap = "viridis")
plt.plot(myline, mymodel(myline))
plt.show()

# %%
mymodel
# Out:
# poly1d([-3.03208795e-02,  1.34333191e+00, -1.55383039e+01,  1.13768037e+02])

# %%
len(myline)
# Out:
# 100

# %% [markdown]
# # Polynomial Regression

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

# %%
len(x)
# Out:
# 18

# %%
plt.scatter(x, y)
plt.show()

# %%
import numpy as np

# %%
model = np.poly1d(np.polyfit(x, y, 3))

# %% [markdown]
# <i><b>in this code above, 3 is the degree of this polyfit</b></i>

# %%
line = np.linspace(1, 22, 100)

# %%
plt.scatter(x, y)
plt.plot(line, model(line))
plt.grid()
plt.show()

# %% [markdown]
# # R-Squared

# %% [markdown]
# It is important to know how well the relationship between the values of the x- and y-axis is, if there are no relationship the polynomial regression can not be used to predict anything.
#
# The relationship is measured with a value called the r-squared.
#
# The r-squared value ranges from 0 to 1, where 0 means no relationship, and 1 means 100% related.
#
# Python and the Sklearn module will compute this value for you, all you have to do is feed it with the x and y arrays:

# %% [markdown]
# # pip install sklearn

# %%
from sklearn.metrics import r2_score

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

# %%
mymodel2 = np.poly1d(np.polyfit(x, y, 3))

print(r2_score(y, mymodel2(x)))
# Out:
# 0.9432150416451027

# %% [markdown]
# <b>Note:</b> The result 0.94 shows that there is a very good relationship, and we can use polynomial regression in future predictions.

# %% [markdown]
# # Predict Future Values

# %% [markdown]
# Now we can use the information we have gathered to predict future values.
#
# Example: Let us try to predict the speed of a car that passes the tollbooth at around the n time
#
# To do so, we need the same mymodel array from the example above:

# %%
import numpy as np
from sklearn.metrics import r2_score

# %%
x
# Out:
# [1, 2, 3, 5, 6, 7, 8, 9, 10, 12, 13, 14, 15, 16, 18, 19, 21, 22]

# %%
y
# Out:
# [100, 90, 80, 60, 60, 55, 60, 65, 70, 70, 75, 76, 78, 79, 90, 99, 99, 100]

# %%
mymodel3 = np.poly1d(np.polyfit(x, y, 3))

# %% [markdown]
# ### Now let's predict the speed

# %%
speed = mymodel3(20) # the value has given as the time hours

# %%
print(speed)
# Out:
# 97.76768832747504

# %% [markdown]
# so the example predicted a speed to be 97.76, which we also could read from the diagram, has given below once again

# %% [markdown]
# #### Call the previous diagram

# %%
plt.scatter(x, y)
plt.plot(line, model(line))
plt.grid()
plt.show()

# %% [markdown]
# # Bad Fit?
#
# Let us create an example where polynomial regression would not be the best method to predict future values.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

# %%
mymodel = np.poly1d(np.polyfit(x, y, 3))
myline = np.linspace(2, 100, 100)

# %%
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# r-squard value for Bad Fit Example:

# %%
from sklearn.metrics import r2_score

# %%
x
# Out:
# [89, 43, 36, 36, 95, 10, 66, 34, 38, 20, 26, 29, 48, 64, 6, 5, 36, 66, 72, 40]

# %%
y
# Out:
# [21, 46, 3, 35, 67, 95, 53, 72, 58, 10, 26, 34, 90, 33, 38, 20, 56, 2, 47, 15]

# %%
mymodel4 = np.poly1d(np.polyfit(x, y, 3))

# %%
print(r2_score(y, mymodel(x)))
# Out:
# 0.009952707566680652

# %% [markdown]
# The result: 0.00995 indicates a very bad relationship, and tells us that this data set is not suitable for polynomial regression.
