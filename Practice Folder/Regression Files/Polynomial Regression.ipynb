# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from scipy import stats
from sklearn.metrics import r2_score

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

# %%
colors = random.sample(range(1, 100), len(x))

# %% [markdown]
# #### Polynomial

# %%
mymodel = np.poly1d(np.polyfit(x, y, 3))
myline = np.linspace(1, 22, 100)

# %%
plt.scatter(x, y, c=colors, cmap="viridis")
plt.plot(myline, mymodel(myline))
# plt.colorbar()
plt.show()

# %% [markdown]
# # R-Squared
#
# R-relationship in Linear Regression

# %%
print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451027

# %% [markdown]
# so it's a good relationship for a future prediction in polynomial regression

# %% [markdown]
# # Predict Future Values

# %%
speed = mymodel(6.5)
print(speed)
# Out:
# 61.19796338601858

# %% [markdown]
# # Bad Fit in Polynomial Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sklearn.metrics import r2_score
from scipy import stats

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

# %%
print(min(x))
print(max(x))
# Out:
# 5
# 95

# %%
newmodel = np.poly1d(np.polyfit(x, y, 3))
newline = np.linspace(5, 95, 100)

# %%
colors = random.sample(range(1, 100), len(x))

# %%
plt.scatter(x, y, c = colors, cmap = "viridis")
plt.plot(newline, newmodel(newline))
plt.show()

# %%
print(r2_score(y, newmodel(x)))
# Out:
# 0.009952707566680652

# %% [markdown]
# This result indicates a very bad relationship, and tells us that this data set is not suitable for polynomial regression.
