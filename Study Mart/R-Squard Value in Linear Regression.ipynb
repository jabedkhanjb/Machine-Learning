# %%
from IPython import display

# %%
display.Image("img/r squard.png")

# %%
display.Image("img/LR graph.png")

# %%
display.Image("img/LR Data line.png")

# %%
display.Image("img/LR data point.png")

# %%
display.Image("img/r_squared value formula.png")

# %% [markdown]
# # Performance Metrics
