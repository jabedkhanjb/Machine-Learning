# %%
from IPython import display

# %%
display.Image("img/linear_regression_with_multiple_variable.png")

# %%
display.Image("img/Linear_formula.png")

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv("car risk with mutliple data.csv")

# %%
df
# Out:
#    speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         NaN    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
df.isnull()
# Out:
#    speed  car_age  experience   risk
# 0  False    False       False  False
# 1  False    False       False  False
# 2  False    False       False  False
# 3  False    False        True  False
# 4  False    False       False  False
# 5  False    False       False  False

# %%
df.experience
# Out:
# 0     5.0
# 1    13.0
# 2     4.0
# 3     NaN
# 4     3.0
# 5     8.0
# Name: experience, dtype: float64

# %%
df.isnull().sum()
# Out:
# speed         0
# car_age       0
# experience    1
# risk          0
# dtype: int64

# %% [markdown]
# ## Error data handling

# %%
df.experience.mean()
# Out:
# 6.6

# %%
df.experience.median()
# Out:
# 5.0

# %%
df["experience"].fillna(5, inplace=True)

# %% [markdown]
# alternative way
#
# exam_fit = df.experience.median()
#
# df.experience = df.experience.fillna(exam_fit)

# %%
df
# Out:
#    speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         5.0    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
regr = linear_model.LinearRegression()

# %%
x = df[["speed", "car_age", "experience"]]
x
# Out:
#    speed  car_age  experience
# 0    200       15         5.0
# 1     90       17        13.0
# 2    165       12         4.0
# 3    110       20         5.0
# 4    140        5         3.0
# 5    115        2         8.0

# %%
y = df["risk"]
y
# Out:
# 0    85
# 1    20
# 2    93
# 3    60
# 4    82
# 5    10
# Name: risk, dtype: int64

# %%
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
regr.predict([[160, 10, 5]])
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([71.37146872])

# %% [markdown]
# ## y = mx + c
#
# y=m1x1 + m2x2 + .............mnxn + c
#
# risk = m1*speed + m2*car_age + m3*experience + intercept

# %%
regr.coef_
# Out:
# array([ 0.33059217,  1.61053246, -6.20772074])

# %%
regr.intercept_
# Out:
# 33.410000910435905

# %%
y =
