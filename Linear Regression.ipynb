# %% [markdown]
# ### Linear Regression

# %% [markdown]
# ##### Firstly we will find the scatter plot by using the data of n number of car's age and their speed level

# %%
import matplotlib.pyplot as mpl

x = [2, 3, 5, 2, 4, 6, 11, 1, 16, 22, 12, 19]
y = [102, 105, 89, 99, 92, 82, 67, 109, 60, 51, 72, 59]

mpl.scatter(x, y)
mpl.show()

# %%
import matplotlib.pyplot as mpl
from scipy import stats

x = [2, 3, 5, 2, 4, 6, 11, 1, 16, 22, 12, 19]
y = [102, 105, 89, 99, 92, 82, 67, 109, 60, 51, 72, 59]
# x = [67, 53, 32, 40, 35]
# y = [95, 97, 80, 85, 91]

slope, intercept, r, p, std_err = stats.linregress(x, y)
print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"r for Relationship: {r}")
print(f"P: {p}")
print(f"STD_ERR: {std_err}")

def myfunction(x):
    return slope * x + intercept

mymodel = list(map(myfunction, x))

mpl.scatter(x, y)
mpl.plot(x, mymodel)
mpl.show()
# Out:
# Slope: -2.6637295969955224
# Intercept: 105.11367904087824
# r for Relationship: -0.9651710753457368
# P: 3.806907611698455e-07
# STD_ERR: 0.22832635963252626

# %% [markdown]
# # Predict Future Values

# %% [markdown]
# ##### For instance, let us try to predict the speed of a n years old car

# %%
speed = myfunction(8)
print(f"So, according to the prediction of our program\nIt predicted the estimate speed of 8 years old \ncar has {speed} KiloMeter per hour.")


print("{:.2f}".format(speed))
# Out:
# So, according to the prediction of our program
# It predicted the estimate speed of 8 years old
# car has 83.80384226491407 KiloMeter per hour.
# 83.80

# %%
import matplotlib.pyplot as plt
import random
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

mycolor = random.sample(range(1,100),len(x))

# linear regression
# need to import stats from scipy

slope, intercept, r, p, std_err = stats.linregress(x,y)

def myfunction(x):
    return slope * x + intercept

mymodel = list(map(myfunction, x))


plt.scatter(x,y,c=mycolor, cmap="viridis")
plt.colorbar()
plt.plot(x,mymodel)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

x = np.array([3,5,6,8,9,2,1,9,23,14,5,19,27,9])
y = np.array([[random.sample(range(90, 120), len(x))]])
yy = y.reshape(-1)
print(yy)

# linregress

slope, intercept, r, p, std_err = stats.linregress(x,yy)

print("Relationship", r)
def mf(x):
    return slope * x + intercept

mymodel = list(map(mf, x))

colors = random.sample(range(1,100), len(x))
plt.scatter(x, yy, c=colors, cmap="viridis")
plt.plot(x, mymodel)
plt.colorbar()
plt.show()
# Out:
# [113 116  99  96 105 119 100  98 111 104 106 107  95 109]
# Relationship -0.27971806425979195

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from scipy import stats

L = [5,7,8,7,2,17,2,9,4,11,12,9,6]

x = random.sample(range(1, 20), len(L))
y = random.sample(range(75, 120), len(L))

colors = random.sample(range(1, 100), len(L))

slope, intercept, r, p, std_err = stats.linregress(x,y)

def mf(x):
    return slope * x + intercept

model = list(map(mf, x))

plt.scatter(x,y,c=colors,cmap="viridis")
plt.plot(x, model)
plt.colorbar()
plt.show()

# %% [markdown]
# # Car Speed Prediction

# %%
# predict the speed of a 10 years old car
import numpy as np
import random
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

# function for predicting speed
def myfunc(z):
    return slope * z + intercept

speed = myfunc(10)


# function for linear regression
def mf(x):
    return slope * x + intercept

mymodel = list(map(mf, x))
print(speed)

plt.scatter(x,y)
plt.plot(x, mymodel)
plt.show()
# Out:
# 85.59308314937454

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

# %%
df = pd.read_csv("CarSpeed.csv")

# %%
df
# Out:
#     Age  Speed
# 0     5     99
# 1     7     86
# 2     8     87
# 3     7     88
# 4     2    111
# 5    17     86
# 6     2    103
# 7     9     87
# 8     4     94
# 9    11     78
# 10   12     77
# 11    9     85
# 12    6     86

# %%
df.head(2)
# Out:
#    Age  Speed
# 0    5     99
# 1    7     86

# %%
df.isnull().any()
# Out:
# Age      False
# Speed    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Age      0
# Speed    0
# dtype: int64

# %%
# Linear regression formula
# y = mx + c

# %% [markdown]
# # Visualization

# %%
x = df[["Age"]]
y = df["Speed"]

# %%
x
# Out:
#     Age
# 0     5
# 1     7
# 2     8
# 3     7
# 4     2
# 5    17
# 6     2
# 7     9
# 8     4
# 9    11
# 10   12
# 11    9
# 12    6

# %%
y
# Out:
# 0      99
# 1      86
# 2      87
# 3      88
# 4     111
# 5      86
# 6     103
# 7      87
# 8      94
# 9      78
# 10     77
# 11     85
# 12     86
# Name: Speed, dtype: int64

# %%
plt.scatter(x,y)
plt.xlabel("Age")
plt.ylabel("Speed")

plt.show()

# %% [markdown]
# # Train Test Data

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.3, random_state = 1)

# %%
xtrain
# Out:
#     Age
# 1     7
# 6     2
# 0     5
# 7     9
# 12    6
# 9    11
# 8     4
# 11    9
# 5    17

# %%
xtest
# Out:
#     Age
# 2     8
# 3     7
# 4     2
# 10   12

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
reg.predict(xtest)
# Out:
# array([89.06488011, 90.27291961, 96.31311707, 84.23272214])
